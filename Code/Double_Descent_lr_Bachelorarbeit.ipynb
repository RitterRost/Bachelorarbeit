# %%
#imports 

# %tensorflow_version 2.x
import tensorflow as tf 
from tensorflow import keras 

#Help-liberies 
import numpy as np
import matplotlib.pyplot as plt

# %%
#The function takes the train labels and the amount of noise we want to apply 
#The return value is the train_labels with noise 
import random

def adding_noise(labels, percent):
  labels_with_noise = np.zeros((len(labels)))
  for i in range(len(labels)):
    r = random.random()
    if r < percent:
      labels_with_noise[i] = int(labels[i] + 1+ 9*random.random())%10
    else:
      labels_with_noise[i] = labels[i] 
  return labels_with_noise

# %% [markdown]
# Creating the Class Model, where modelscan be created, trained and observed

# %%
class Model:
      model = keras.Sequential()

      def __init__(self, layers, layersize,optimiz):

        self.layers = layers
        self.layersize = layersize
        #initializing the model
        self.model = keras.Sequential()
        self.model.add(keras.layers.Flatten(input_shape=(28,28)))#input layer
        for j in range(0, layers):
          self.model.add(keras.layers.Dense(layersize, activation="relu")) #hidden layers
        self.model.add(keras.layers.Dense(10,activation='softmax')) #output layer
        #compile model
        self.model.compile(optimizer= optimiz , 
                           loss= 'sparse_categorical_crossentropy',metrics=['accuracy'])  
        self.model.count_params()

      '''
      trains the model and returns a List of various data
      data[0] = the train loss after fitting the data 
      data[1] = the train accuracy after fitting the data  
      data[2] = the test loss after evaluating the model 
      data[3] = the test accuracy after evaluating the model  
      '''

      def train(self,epoch,datasize,train_images,train_labels,test_images, test_labels):
        data = np.zeros(4)
        print(datasize,epoch)

        #trainig the model until a certain accuracy is reached
        runs = 0
        train_loss = 100
        train_acc = 0
        e_per_run = 5
        while (train_loss > 0.005) and runs < epoch:
          history = self.model.fit(train_images[:datasize], train_labels[:datasize],epochs = e_per_run)
          train_loss_all, train_acc_all = history.history.values()
          train_loss = train_loss_all[e_per_run-1]
          train_acc = train_acc_all[e_per_run-1]
          runs = runs + e_per_run

        test_loss, test_acc = self.model.evaluate(test_images, test_labels, verbose=1)
        data[0] = train_loss
        data[1] = train_acc
        data[2] = test_loss
        data[3] = test_acc
        print(self.model.summary())
        return data

      def getParameter(self):
        return self.model.count_params()

# %%
def trainModel(amount,min_layersize,max_layersize, layers, epochs, datasize, noise, optimizer):
  a = max_layersize - min_layersize 
  data = np.zeros((5,a))

  #load dataset MNIST
  mnist = keras.datasets.mnist
  #spliting into testing and training
  (train_images, train_labels_without_noise), (test_images, test_labels) = mnist.load_data()
  #normalizing data
  train_images = train_images/255.0
  test_images = test_images/255.0
  #adding noise
  train_labels = adding_noise(train_labels_without_noise, noise)

  
  '''
  data[0][i] = the train loss after fitting the data in iterration i (with i layers) 
  data[1][i] = the train accuracy after fitting the data in iterration i (with i layers)  
  data[2][i] = the test loss after evaluating the model in iterration i (with i layers) 
  data[3][i] = the test accuracy after evaluating the model in iterration i (with i layers) 
  data[4][i] = the parameters of the model in iterration i (with i layers)
  '''

  for i in range(0,max_layersize - min_layersize):
    data_help = [0,0,0,0,0]
    for j in range(0,amount):
      print("I an currently in run ",i, " ===> The model has ", i+ min_layersize ,"neurons. ")
      print("amount =", amount) 
      myModel = Model(layers,i + min_layersize, optimizer)
      history = myModel.train(epochs, datasize,train_images,train_labels,test_images, test_labels)
      param   = myModel.getParameter()
      data_help[0] = data_help[0] + history[0] 
      data_help[1] = data_help[1] + history[1]
      data_help[2] = data_help[2] + history[2]
      data_help[3] = data_help[3] + history[3]
      data_help[4] = data_help[4] + param

    #maby filtering runs, that went wrong
    data[0][i] = data_help[0]/amount
    data[1][i] = data_help[1]/amount
    data[2][i] = data_help[2]/amount
    data[3][i] = data_help[3]/amount
    data[4][i] = data_help[4]
  return data

# %%
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from matplotlib import cm


optimizer = ["learning rate = 0.01","learning rate = 0.05", "learning rate = 0.1" ]
data = []
data.append(trainModel(4,1,80,1,200,20000, 0,tf.keras.optimizers.SGD(learning_rate=0.01)))
data.append(trainModel(4,1,80,1,200,20000, 0,tf.keras.optimizers.SGD(learning_rate=0.05)))
data.append(trainModel(4,1,80,1,200,20000, 0,tf.keras.optimizers.SGD(learning_rate=0.1)))

 
viridis = cm.get_cmap('viridis', 12)
colors = [viridis(x) for x in np.linspace(0.3,0.9,len(data))]

fig, ax = plt.subplots(1)
fig.set_size_inches(20,15)
for i in range(len(data)):
  ax.plot(data[i][2],linewidth=3.0, label = optimizer[i] ) 
  #ax.plot(data[i][0],linewidth=2.0) 

ax.set_xlabel('Layersize')
ax.set_ylabel('loss')      
ax.legend(loc='upper right')
plt.savefig("different learningrates")
# Out:
# I an currently in run  0  ===> The model has  78 neurons.
# amount = 1
# 20000 20
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 1.0864 - accuracy: 0.7341
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4930 - accuracy: 0.8753
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3989 - accuracy: 0.8935
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3551 - accuracy: 0.9039
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3277 - accuracy: 0.9112
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3080 - accuracy: 0.9152
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2916 - accuracy: 0.9194
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2781 - accuracy: 0.9230
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2663 - accuracy: 0.9262
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2558 - accuracy: 0.9294
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2464 - accuracy: 0.9319
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2377 - accuracy: 0.9345
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2297 - accuracy: 0.9362
# Epoch 4/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2222 - accuracy: 0.9388
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2151 - accuracy: 0.9399
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2088 - accuracy: 0.9421
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2022 - accuracy: 0.9446
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1966 - accuracy: 0.9448
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1915 - accuracy: 0.9469
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1862 - accuracy: 0.9487
# 313/313 [==============================] - 1s 1ms/step - loss: 0.2080 - accuracy: 0.9411
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_4 (Flatten)         (None, 784)               0
#
#  dense_8 (Dense)             (None, 78)                61230
#
#  dense_9 (Dense)             (None, 10)                790
#
# =================================================================
# Total params: 62,020
# Trainable params: 62,020
# Non-trainable params: 0
# _________________________________________________________________
# None
# I an currently in run  1  ===> The model has  79 neurons.
# amount = 1
# 20000 20
# Epoch 1/5
# 625/625 [==============================] - 2s 2ms/step - loss: 1.0742 - accuracy: 0.7336
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4978 - accuracy: 0.8737
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4038 - accuracy: 0.8911
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3607 - accuracy: 0.9022
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3330 - accuracy: 0.9086
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3131 - accuracy: 0.9139
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2961 - accuracy: 0.9172
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2825 - accuracy: 0.9218
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2702 - accuracy: 0.9250
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2595 - accuracy: 0.9281
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2499 - accuracy: 0.9305
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2409 - accuracy: 0.9341
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2331 - accuracy: 0.9353
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2253 - accuracy: 0.9369
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2181 - accuracy: 0.9398
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2116 - accuracy: 0.9415
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2056 - accuracy: 0.9431
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1995 - accuracy: 0.9448
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1940 - accuracy: 0.9463
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1890 - accuracy: 0.9478
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2119 - accuracy: 0.9393
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_5 (Flatten)         (None, 784)               0
#
#  dense_10 (Dense)            (None, 79)                62015
#
#  dense_11 (Dense)            (None, 10)                800
#
# =================================================================
# Total params: 62,815
# Trainable params: 62,815
# Non-trainable params: 0
# _________________________________________________________________
# None
# I an currently in run  0  ===> The model has  78 neurons.
# amount = 1
# 20000 20
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.5565 - accuracy: 0.8494
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2996 - accuracy: 0.9147
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2489 - accuracy: 0.9289
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2127 - accuracy: 0.9398
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1863 - accuracy: 0.9476
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1657 - accuracy: 0.9534
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1488 - accuracy: 0.9578
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1338 - accuracy: 0.9624
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1215 - accuracy: 0.9656
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1113 - accuracy: 0.9693
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1012 - accuracy: 0.9733
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0929 - accuracy: 0.9744
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0862 - accuracy: 0.9774
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0793 - accuracy: 0.9790
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0729 - accuracy: 0.9811
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0677 - accuracy: 0.9833
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0635 - accuracy: 0.9839
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0593 - accuracy: 0.9855
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0552 - accuracy: 0.9867
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0517 - accuracy: 0.9876
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1281 - accuracy: 0.9621
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_6 (Flatten)         (None, 784)               0
#
#  dense_12 (Dense)            (None, 78)                61230
#
#  dense_13 (Dense)            (None, 10)                790
#
# =================================================================
# Total params: 62,020
# Trainable params: 62,020
# Non-trainable params: 0
# _________________________________________________________________
# None
# I an currently in run  1  ===> The model has  79 neurons.
# amount = 1
# 20000 20
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.5575 - accuracy: 0.8523
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2974 - accuracy: 0.9166
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2475 - accuracy: 0.9308
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2127 - accuracy: 0.9410
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1866 - accuracy: 0.9467
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1652 - accuracy: 0.9547
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1478 - accuracy: 0.9586
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1343 - accuracy: 0.9628
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1212 - accuracy: 0.9669
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1112 - accuracy: 0.9694
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1017 - accuracy: 0.9721
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0926 - accuracy: 0.9751
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0861 - accuracy: 0.9772
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0796 - accuracy: 0.9790
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0736 - accuracy: 0.9803
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0676 - accuracy: 0.9826
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0629 - accuracy: 0.9840
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0589 - accuracy: 0.9857
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0545 - accuracy: 0.9870
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0508 - accuracy: 0.9885
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1239 - accuracy: 0.9628
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 784)               0
#
#  dense_14 (Dense)            (None, 79)                62015
#
#  dense_15 (Dense)            (None, 10)                800
#
# =================================================================
# Total params: 62,815
# Trainable params: 62,815
# Non-trainable params: 0
# _________________________________________________________________
# None
# I an currently in run  0  ===> The model has  78 neurons.
# amount = 1
# 20000 20
# Epoch 1/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.4467 - accuracy: 0.8723
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2387 - accuracy: 0.9321
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1825 - accuracy: 0.9486
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1460 - accuracy: 0.9589
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1223 - accuracy: 0.9653
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1038 - accuracy: 0.9705
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0882 - accuracy: 0.9758
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0765 - accuracy: 0.9793
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0672 - accuracy: 0.9821
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0574 - accuracy: 0.9855
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0510 - accuracy: 0.9868
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0440 - accuracy: 0.9890
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0392 - accuracy: 0.9904
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0346 - accuracy: 0.9923
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0296 - accuracy: 0.9941
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0262 - accuracy: 0.9949
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0232 - accuracy: 0.9965
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0204 - accuracy: 0.9971
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0184 - accuracy: 0.9975
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0163 - accuracy: 0.9980
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1159 - accuracy: 0.9675
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_8 (Flatten)         (None, 784)               0
#
#  dense_16 (Dense)            (None, 78)                61230
#
#  dense_17 (Dense)            (None, 10)                790
#
# =================================================================
# Total params: 62,020
# Trainable params: 62,020
# Non-trainable params: 0
# _________________________________________________________________
# None
# I an currently in run  1  ===> The model has  79 neurons.
# amount = 1
# 20000 20
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4502 - accuracy: 0.8709
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2375 - accuracy: 0.9318
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1811 - accuracy: 0.9488
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1447 - accuracy: 0.9599
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1227 - accuracy: 0.9653
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1046 - accuracy: 0.9702
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0900 - accuracy: 0.9744
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0780 - accuracy: 0.9780
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0665 - accuracy: 0.9811
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0595 - accuracy: 0.9844
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0517 - accuracy: 0.9866
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0454 - accuracy: 0.9880
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0400 - accuracy: 0.9905
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0356 - accuracy: 0.9916
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0316 - accuracy: 0.9933
# Epoch 1/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0275 - accuracy: 0.9944
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0239 - accuracy: 0.9963
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0216 - accuracy: 0.9966
# Epoch 4/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0193 - accuracy: 0.9968
# Epoch 5/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.0171 - accuracy: 0.9979
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1163 - accuracy: 0.9680
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_9 (Flatten)         (None, 784)               0
#
#  dense_18 (Dense)            (None, 79)                62015
#
#  dense_19 (Dense)            (None, 10)                800
#
# =================================================================
# Total params: 62,815
# Trainable params: 62,815
# Non-trainable params: 0
# _________________________________________________________________
# None
